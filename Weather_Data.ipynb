# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing

# %%
xls = pd.ExcelFile('WeatherData.xlsx')
df1 = pd.read_excel(xls, '2009')
df2 = pd.read_excel(xls, '2010')
df3 = pd.read_excel(xls, '2011')
df4 = pd.read_excel(xls, '2012')
df5 = pd.read_excel(xls, '2013')
df6 = pd.read_excel(xls, '2014')
df7 = pd.read_excel(xls, '2015')
df8 = pd.read_excel(xls, '2016')

# %%
#df1

# %%
df1.head()
# Out:
#    Year Month  Day  Temp high (°C)  Temp avg (°C)  Temp low (°C)  \
# 0  2009   Jan    1              -3             -6             -9
# 1  2009   Jan    2               1             -2             -5
# 2  2009   Jan    3               3              1             -2
# 3  2009   Jan    4               6              1             -4
# 4  2009   Jan    5               6              5              3
#
#    Dew Point high (°C)  Dew Point avg (°C)  Dew Point low (°C)  \
# 0                  -16                 -17                 -19
# 1                   -3                  -7                 -17
# 2                   -5                  -9                 -13
# 3                  -10                 -12                 -13
# 4                   -1                  -5                 -16
#
#    Humidity (%) high     ...       Sea Level Press. (hPa) avg  \
# 0                 54     ...                             1023
# 1                 78     ...                             1012
# ...

# %%
df1['Month'] = df1['Month'].replace('Jan',1)
df1['Month'] = df1['Month'].replace('Feb',2)
df1['Month'] = df1['Month'].replace('Mar',3)
df1['Month'] = df1['Month'].replace('Apr',4)
df1['Month'] = df1['Month'].replace('May',5)
df1['Month'] = df1['Month'].replace('Jun',6)
df1['Month'] = df1['Month'].replace('Jul',7)
df1['Month'] = df1['Month'].replace('Aug',8)
df1['Month'] = df1['Month'].replace('Sep',9)
df1['Month'] = df1['Month'].replace('Oct',10)
df1['Month'] = df1['Month'].replace('Nov',11)
df1['Month'] = df1['Month'].replace('Dec',12)

#or df1.month = df.month.map({'Jan':1,'Feb':2,'Mar':3.....})

# %%
df1.isna().sum()
# Out:
# Year                           0
# Month                          0
# Day                            0
# Temp high (°C)                 0
# Temp avg (°C)                  0
# Temp low (°C)                  0
# Dew Point high (°C)            0
# Dew Point avg (°C)             0
# Dew Point low (°C)             0
# Humidity (%) high              0
# Humidity (%) avg               0
# Humidity (%) low               0
# Sea Level Press. (hPa) high    0
# Sea Level Press. (hPa) avg     0
# Sea Level Press. (hPa) low     0
# Visibility (km) high           0
# Visibility (km) avg            0
# Visibility (km) low            0
# Wind (km/h) low                0
# Wind (km/h) avg                0
# Wind (km/h) high               0
# Precip. (mm) sum               0
# WeatherEvent                   0
# dtype: int64

# %%
df1['WeatherEvent'] = df1['WeatherEvent'].fillna('Normal')

# %%
df1.head(2)
# Out:
#    Year  Month  Day  Temp high (°C)  Temp avg (°C)  Temp low (°C)  \
# 0  2009      1    1              -3             -6             -9
# 1  2009      1    2               1             -2             -5
#
#    Dew Point high (°C)  Dew Point avg (°C)  Dew Point low (°C)  \
# 0                  -16                 -17                 -19
# 1                   -3                  -7                 -17
#
#    Humidity (%) high     ...       Sea Level Press. (hPa) avg  \
# 0                 54     ...                             1023
# 1                 78     ...                             1012
#
#    Sea Level Press. (hPa) low  Visibility (km) high  Visibility (km) avg  \
# 0                        1015                    16                   16
# 1                        1007                    16                   13
#
#    Visibility (km) low  Wind (km/h) low  Wind (km/h) avg  Wind (km/h) high  \
# 0                   16               37               18                60
# ...

# %%
df1.shape
# Out:
# (365, 23)

# %%
df1.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Temp high (°C)', 'Temp avg (°C)',
#        'Temp low (°C)', 'Dew Point high (°C)', 'Dew Point avg (°C)',
#        'Dew Point low (°C)', 'Humidity (%) high', 'Humidity (%) avg',
#        'Humidity (%) low', 'Sea Level Press. (hPa) high',
#        'Sea Level Press. (hPa) avg', 'Sea Level Press. (hPa) low',
#        'Visibility (km) high', 'Visibility (km) avg', 'Visibility (km) low',
#        'Wind (km/h) low', 'Wind (km/h) avg', 'Wind (km/h) high',
#        'Precip. (mm) sum', 'WeatherEvent'],
#       dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 23 columns):
# Year                           365 non-null int64
# Month                          365 non-null int64
# Day                            365 non-null int64
# Temp high (°C)                 365 non-null int64
# Temp avg (°C)                  365 non-null int64
# Temp low (°C)                  365 non-null int64
# Dew Point high (°C)            365 non-null int64
# Dew Point avg (°C)             365 non-null int64
# Dew Point low (°C)             365 non-null int64
# Humidity (%) high              365 non-null int64
# Humidity (%) avg               365 non-null int64
# Humidity (%) low               365 non-null int64
# Sea Level Press. (hPa) high    365 non-null int64
# Sea Level Press. (hPa) avg     365 non-null int64
# Sea Level Press. (hPa) low     365 non-null int64
# Visibility (km) high           365 non-null int64
# Visibility (km) avg            365 non-null int64
# ...

# %%
df1 = df1.replace('-',0)

# %%
df1['Wind\xa0(km/h) avg'] = df1['Wind\xa0(km/h) avg'].replace('0',df1['Wind\xa0(km/h) avg'].mean())

# %%
df1['Wind\xa0(km/h) high'] = df1['Wind\xa0(km/h) high'].replace('0',df1['Wind\xa0(km/h) high'].mean())
df1['Wind\xa0(km/h) low'] = df1['Wind\xa0(km/h) low'].replace('0',df1['Wind\xa0(km/h) low'].mean())

# %%
df1['Precip.\xa0(mm) sum'] = df1['Precip.\xa0(mm) sum'].replace('T',0.254)

# %%
df1['Year'] = df1['Year'].astype('int')

# %%
D1 = df1.groupby('Month').mean() #2009
# Out:
#        Year   Day  Temp high (°C)  Temp avg (°C)  Temp low (°C)  \
# Month
# 1      2009  16.0        0.741935      -2.096774      -5.322581
# 2      2009  14.5        6.964286       2.785714      -1.642857
# 3      2009  16.0        9.838710       5.967742       1.774194
# 4      2009  15.5       17.100000      12.733333       7.833333
# 5      2009  16.0       21.354839      17.000000      12.483871
# 6      2009  15.5       23.666667      19.866667      15.833333
# 7      2009  16.0       26.838710      22.741935      18.225806
# 8      2009  16.0       27.967742      24.387097      20.548387
# 9      2009  15.5       22.766667      19.233333      15.333333
# 10     2009  16.0       16.258065      12.870968       9.354839
# 11     2009  15.5       13.733333      10.800000       7.566667
# 12     2009  16.0        5.451613       2.354839      -1.032258
#
#        Dew Point high (°C)  Dew Point avg (°C)  Dew Point low (°C)  \
# Month
# ...
